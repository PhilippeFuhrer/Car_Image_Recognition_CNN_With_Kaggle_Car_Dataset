# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import cv2
 
import keras
from keras import models, layers
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Import Data

# %% [markdown]
#  **Mount Google drive for better perfomance**

# %%
from google.colab import drive
 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Import Images**

# %%
images = glob.glob('/content/gdrive/MyDrive/Kaggle/Dataset/*.jpg') # Daten von lokal importieren

# %% [markdown]
# **Extract Brand from image name**

# %%
data = pd.DataFrame(images, columns=['src']) # kolumnen von source-pfad ableiten
data['brand'] = data['src'].apply(lambda x : x.split('_')[0].split("/")[-1]) # _ als kolumnen split anerkennen etc. -> brand erkennen
data['brand'].value_counts().head(20) # Anzahl der car images pro brand ausgeben

# %%
data = data[(data['brand']=='Volkswagen')|(data['brand']=='Toyota')|(data['brand']=='Ford')|(data['brand']=='BMW')|(data['brand']=='Nissan')|(data['brand']=='Audi')|(data['brand']=='Mercedes-Benz')|(data['brand']=='Honda')|(data['brand']=='Kia')|(data['brand']=='Volvo')].reset_index(drop=True)

data
# Out:
#                                                      src  brand
# 0      /content/gdrive/MyDrive/Kaggle/Dataset/Volvo_X...  Volvo
# 1      /content/gdrive/MyDrive/Kaggle/Dataset/Volvo_X...  Volvo
# 2      /content/gdrive/MyDrive/Kaggle/Dataset/Volvo_V...  Volvo
# 3      /content/gdrive/MyDrive/Kaggle/Dataset/Volvo_X...  Volvo
# 4      /content/gdrive/MyDrive/Kaggle/Dataset/Volvo_X...  Volvo
# ...                                                  ...    ...
# 31057  /content/gdrive/MyDrive/Kaggle/Dataset/Audi_A4...   Audi
# 31058  /content/gdrive/MyDrive/Kaggle/Dataset/Audi_A4...   Audi
# 31059  /content/gdrive/MyDrive/Kaggle/Dataset/Audi_A4...   Audi
# 31060  /content/gdrive/MyDrive/Kaggle/Dataset/Audi_A4...   Audi
# 31061  /content/gdrive/MyDrive/Kaggle/Dataset/Audi_A4...   Audi
#
# [31062 rows x 2 columns]

# %% [markdown]
# # Feature engineering

# %% [markdown]
# **Change images to grey**

# %%
X= []
y= []
for i in range(len(data)):
    src = data.loc[i,'src']
    src = cv2.imread(src, cv2.IMREAD_COLOR)
    dst = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
    X.append(cv2.resize(dst, dsize=(200, 300), interpolation=cv2.INTER_AREA))
    y.append(data.loc[i,'brand'])
    
fig, axes = plt.subplots(1,10,figsize=(25,10))
for i in range(0,10):
    axes[i].imshow(X[i])

# %% [markdown]
# **Reshape array**

# %%
X = np.array(X)
X = X.astype('float32')
X = X /255.0
X = X.reshape(-1,300,200,1)
y= np.array(pd.get_dummies(pd.DataFrame(y),columns=[0]))

X.shape, y.shape

# %% [markdown]
# # Save array

# %% [markdown]
# **Save to numpy array for further use**

# %%
np.save('/content/gdrive/MyDrive/Kaggle/ScaledImage/ScaldedImageX', X)
np.save('/content/gdrive/MyDrive/Kaggle/ScaledImage/ScaldedImagey', y)
